# %% [markdown]
# # Sports Analysis - Data Imports
# This notebook is set up for importing and analyzing sports data.

# %%
# Import libraries we'll be working with in this part
import pandas as pd
import sqlite3 as sql

# %%
# Load data and check how they are organized and what is the overall set-up 
df = pd.read_csv("athletes.csv")
df.head()
df.columns
# Out:
# Index(['athlete_id', 'name', 'region', 'team', 'affiliate', 'gender', 'age',
#        'height', 'weight', 'fran', 'helen', 'grace', 'filthy50', 'fgonebad',
#        'run400', 'run5k', 'candj', 'snatch', 'deadlift', 'backsq', 'pullups',
#        'eat', 'train', 'background', 'experience', 'schedule', 'howlong'],
#       dtype='str')
